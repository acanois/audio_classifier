# %%
import os
import pandas as pd
import audio_analyzer

data_path = os.path.join('data', 'audio')

# %%
audio_analyzer.create_spectrogram(os.path.join(data_path, 'fold1', '101415-3-0-2.wav'), 'fold2', 'test.png')
# Out:
# processing data/images/fold2/test.png

# %%
os.listdir(data_path)
# Out:
# ['fold2',
#  'fold5',
#  'fold4',
#  'fold3',
#  '.DS_Store',
#  'fold8',
#  'fold6',
#  'fold1',
#  'fold7',
#  'fold9',
#  'fold10']

# %%
for folder in os.listdir(data_path):
    if folder != '.DS_Store':
        curr_path = os.path.join(data_path, folder)
        for file in os.listdir(curr_path):
            if file != '.DS_Store':
                output_path = os.path.join(data_path, folder, file)
                audio_analyzer.create_spectrogram(output_path, folder, file.replace('.wav', '.png'))
# Out:
# processing data/images/fold2/203929-7-5-1.png
# processing data/images/fold2/196384-9-0-2.png
# processing data/images/fold2/169098-7-4-6.png
# processing data/images/fold2/123688-8-0-4.png
# processing data/images/fold2/174994-3-0-0.png
# processing data/images/fold2/18453-3-0-0.png
# processing data/images/fold2/109703-2-0-134.png
# processing data/images/fold2/147926-0-0-44.png
# processing data/images/fold2/123688-8-0-13.png
# processing data/images/fold2/203929-7-7-3.png
# processing data/images/fold2/147926-0-0-50.png
# processing data/images/fold2/169098-7-4-11.png
# processing data/images/fold2/98202-9-0-10.png
# processing data/images/fold2/156893-7-6-0.png
# processing data/images/fold2/189023-0-0-0.png
# processing data/images/fold2/203929-7-6-10.png
# processing data/images/fold2/96475-9-0-5.png
# processing data/images/fold2/159747-8-0-17.png
# processing data/images/fold2/169098-7-0-2.png
# processing data/images/fold2/201652-5-4-9.png
# ...
